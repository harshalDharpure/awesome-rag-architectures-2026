# %% [markdown]
# # 📚 Long-Context RAG Tutorial
#
# Using **100K+ token context windows** for full document understanding.

# %%
import sys; sys.path.insert(0, '../..')
from dotenv import load_dotenv; load_dotenv()
from long_context import LongContextRAG

document = """# SERVICE AGREEMENT
## Fees: Basic $5,000/mo, Professional $12,000/mo, Enterprise $25,000/mo
## Term: 12 months with auto-renewal"""

rag = LongContextRAG(llm_model="gpt-4o")
result = rag.query("What are the pricing tiers?", document)
print(f"Answer: {result.answer}")
