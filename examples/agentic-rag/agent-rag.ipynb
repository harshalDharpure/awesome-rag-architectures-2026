# %% [markdown]
# # 🤖 Agentic RAG Tutorial
#
# Autonomous reasoning with **planning, tool use, and self-correction**.

# %%
import sys; sys.path.insert(0, '../..')
from dotenv import load_dotenv; load_dotenv()
from agent_rag import AgenticRAG

docs = [{"content": "2024 Revenue: $18.7B, 2023: $16.3B, 2022: $14.5B"}]
rag = AgenticRAG(tools=["search", "calculate"], max_iterations=5)
rag.index_documents(docs)

result = rag.query("Calculate the CAGR from 2022 to 2024")
print(f"Tools: {result.tools_used}, Answer: {result.answer}")
